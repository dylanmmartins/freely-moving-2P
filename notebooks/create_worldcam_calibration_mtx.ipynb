# %%
import fm2p
# Out:
# Loading DLC 2.3.7...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)
# c:\Users\dmartins\anaconda3\envs\fm1\lib\site-packages\oasis\functions.py:13: UserWarning: Could not find cvxpy. Don't worry, you can still use OASIS, just not the slower interior point methods we compared to in the papers.
#   warn("Could not find cvxpy. Don't worry, you can still use OASIS, " +

# %%
video_path = r'T:\camera_calibration\230303_DMM_DMM001_worldcam_calibration\230303_DMM_DMM001_worldcam_calibration_01.avi'

# %%
deinterlaced_path = fm2p.deinterlace(video_path)
# Out:
# Deinterlacing 230303_DMM_DMM001_worldcam_calibration_01.avi

# %%
deinterlaced_path = r'T:\camera_calibration\230303_DMM_DMM001_worldcam_calibration\230303_DMM_DMM001_worldcam_calibration_01_deinter.avi'

# %%
mtx_savepath = video_path = r'T:\camera_calibration\worldcam_01_calibration_mtx.npz'

fm2p.compute_camera_distortion(deinterlaced_path, mtx_savepath)
# Out:
# Finding chessboard corners for each frame
# 100%|██████████| 9610/9610 [02:31<00:00, 63.58it/s]
# Calculating calibration correction
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 3
#       1 mtx_savepath = video_path = r'T:\camera_calibration\worldcam_01_calibration_mtx.npz'
# ----> 3 fm2p.compute_camera_distortion(deinterlaced_path, mtx_savepath)
#
# File c:\users\dmartins\documents\github\freely-moving-retinotoego\fm2p\utils\cameras.py:287, in compute_camera_distortion(video_path, savepath, boardw, boardh)
#     285 # Calibrate the camera (this is a little slow)
#     286 print('Calculating calibration correction')
# --> 287 ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints,
#     288                                                 gray.shape[::-1], None, None)
#     290 # Format as .npz and save the file
# ...

# %%
fm2p.undistort_video()
