# %%
import numpy as np
import matplotlib.pyplot as plt
import fm2p
# Out:
# Loading DLC 2.3.7...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)
# c:\Users\dmartins\anaconda3\envs\fm1\lib\site-packages\oasis\functions.py:13: UserWarning: Could not find cvxpy. Don't worry, you can still use OASIS, just not the slower interior point methods we compared to in the papers.
#   warn("Could not find cvxpy. Don't worry, you can still use OASIS, " +

# %%
import matplotlib as mpl
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.size'] = 7

# %%
top_avi = r'K:\Mini2P\250306_DMM_DMM042_pillar\fm1\fm1_0001.mp4'
frame = fm2p.load_video_frame(top_avi, fr=np.nan, ds=1.)
# Out:
# Reading frame 2000 from fm1_0001.mp4

# %%
top_h5 = r'K:\Mini2P\250306_DMM_DMM042_pillar\fm1\250306_DMM_DMM042_pillar_fm1DLC_Resnet50_trackbar-v5Mar24shuffle1_snapshot_080.h5'
top_data, _ = fm2p.open_dlc_h5(top_h5)

# %%
plt.figure(dpi=300)
plt.imshow(frame, cmap='gray')
plt.plot(top_data['pad_r_x'][500], top_data['pad_r_y'][500], 'o')

# %%
eye_avi = r'K:\Mini2P\250306_DMM_DMM038_pillar\fm2\250306_DMM_DMM038_fm_2_eyecam_deinter.avi'
eyeframe = fm2p.load_video_frame(eye_avi, fr=5005, ds=1.)
# Out:
# Reading frame 5005 from 250306_DMM_DMM038_fm_2_eyecam_deinter.avi

# %%
fig, ax = plt.subplots(1,1,dpi=300,figsize=(3,3))
ax.imshow(eyeframe, cmap='gray', vmin=0, vmax=255)
ax.axis('off')
ax.set_xlim([0,480])
fig.tight_layout()
fig.savefig('demo_eye_frame.svg')
